# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab

from wolframclient.evaluation import WolframLanguageSession
from wolframclient.language import wl, wlexpr

# %%
# session = WolframLanguageSession()
# data = session.evaluate(wlexpr('Get["PermTherm.FreeEnergyData"]'))

# %%
# df = pd.DataFrame(data[0])
# for i in range(1,len(data)):
#     df = df.merge(pd.DataFrame(data[i]),on=0,suffixes=(None,'_'+str('i')))

# df.columns = ['l',2,4,6,8,10]

# %%
#df.to_csv('PermTherm.FreeEnergyData.csv', index=False)

# %%
df = pd.read_csv('PermTherm.FreeEnergyData.csv')

# %%
font = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : 26}

matplotlib.rc('font', **font)
matplotlib.rcParams['figure.figsize'] = 6.4,4.8

ax = df.plot('l',linewidth=0.4)
plt.ylabel(r'$G_{\mathbf{x},l}-\langle G \rangle$')
plt.xlabel('$l$')
plt.legend(title='$\Delta G_{T,22}$')
plt.xticks(np.arange(0, 10001, 2500))
plt.yticks(np.arange(-200, 201,100))
h, l = ax.get_legend_handles_labels()
plt.gca().set_ylim([-250, 220])
plt.legend().remove()
plt.tight_layout(pad = 0)
plt.gcf().set_size_inches(9.6, 5.4)

plt.savefig('FEPermTherm.eps')

# %%
ax = df.plot('l',linewidth=0.4)
legend = ax.legend(framealpha=1,title='$\Delta G_{TT/PT,22}$',bbox_to_anchor=(1.1, 1.05))
#legend = ax.legend(h,l,framealpha=1, loc = 3, title='$\Delta G_{T,22}$')
legend.get_frame().set_linewidth(0.0)
bbox = legend.get_window_extent(plt.gcf().canvas.get_renderer()).transformed(plt.gcf().dpi_scale_trans.inverted())

plt.savefig('PermLegend.eps',bbox_inches = bbox)

# %%
ax

# %%
s = list(data[1][1])

# %%
s.insert(0,2)

# %%
s
# Out:
# [2, 0.10000000000000009, 1.3861870276544553e-07]

# %%
[x for row in predata for item in row for x in item]
# Out:
# [2,
#  0.0,
#  0.02603023896712745,
#  2,
#  0.10000000000000009,
#  1.3817929078392654,
#  2,
#  0.19999999999999996,
#  2.2095440782894196,
#  2,
#  0.30000000000000004,
#  2.7870100799118016,
#  2,
#  0.3999999999999999,
#  3.2212034471267637,
#  2,
#  0.5,
#  3.5630660473634213,
#  2,
#  0.6000000000000001,
#  3.840863496800693,
#  2,
#  0.7000000000000002,
#  4.0718830051896235,
#  2,
#  0.8,
#  4.267413855426444,
#  2,
#  0.8999999999999999,
#  4.435173872400738,
#  2,
#  1.0,
#  4.580614592367239,
#  2,
#  1.1,
#  4.707679151441819,
#  2,
#  1.2000000000000002,
#  4.8192704833921,
#  2,
#  1.3,
#  4.9175558034057705,
#  2,
#  1.4000000000000001,
#  5.004173140551252,
#  2,
#  1.5,
#  5.080376009569422,
#  2,
#  1.6,
#  5.14713688550532,
#  2,
#  1.7000000000000002,
#  5.205221860785714,
#  2,
#  1.8,
#  5.255244351609525,
#  2,
#  1.9000000000000001,
#  5.297703236877244,
#  2,
#  2.0,
#  5.333009398081157,
#  2,
#  2.1,
#  5.361503744853805,
#  2,
#  2.2,
#  5.38346917298443,
#  2,
#  2.3000000000000003,
#  5.399138378546762,
#  2,
#  2.4000000000000004,
#  5.408698998616908,
#  2,
#  2.5,
#  5.41229716056828,
#  2,
#  2.6,
#  5.410040203311375,
#  2,
#  2.7,
#  5.4019990870722,
#  2,
#  2.8000000000000003,
#  5.388210828456855,
#  2,
#  2.9000000000000004,
#  5.368681174252998,
#  2,
#  3.0,
#  5.343387647849629,
#  2,
#  3.1,
#  5.312283053538955,
#  2,
#  3.2,
#  5.275299495178646,
#  2,
#  3.3000000000000003,
#  5.232352947820025,
#  2,
#  3.4000000000000004,
#  5.183348407232856,
#  2,
#  3.5,
#  5.128185627979844,
#  2,
#  3.6,
#  5.06676544254371,
#  2,
#  3.7,
#  4.998996629944461,
#  2,
#  3.8000000000000003,
#  4.924803271326808,
#  2,
#  3.9000000000000004,
#  4.844132492119797,
#  2,
#  4.0,
#  4.756962446530573,
#  2,
#  4.1000000000000005,
#  4.663310352306342,
#  2,
#  4.2,
#  4.563240334916521,
#  2,
#  4.3,
#  4.456870794630623,
#  2,
#  4.4,
#  4.344380972311013,
#  2,
#  4.5,
#  4.226016365592473,
#  2,
#  4.6000000000000005,
#  4.102092641968065,
#  2,
#  4.7,
#  3.9729977140289168,
#  2,
#  4.800000000000001,
#  3.839191688132966,
#  2,
#  4.9,
#  3.7012044722943487,
#  2,
#  5.0,
#  3.5596309303802376,
#  2,
#  5.1000000000000005,
#  3.4151235927416184,
#  2,
#  5.2,
#  3.268383069974229,
#  2,
#  5.300000000000001,
#  3.1201464556848455,
#  2,
#  5.4,
#  2.971174133473614,
#  2,
#  5.5,
#  2.8222355102916885,
#  2,
#  5.6000000000000005,
#  2.674094271934333,
#  2,
#  5.7,
#  2.5274937888648514,
#  2,
#  5.800000000000001,
#  2.383143288307449,
#  2,
#  5.9,
#  2.241705352907085,
#  2,
#  6.0,
#  2.1037852131550943,
#  2,
#  6.1000000000000005,
#  1.969922179916798,
#  2,
#  6.199999999999999,
#  1.8405834267597467,
#  2,
#  6.300000000000001,
#  1.7161601921046499,
#  2,
#  6.4,
#  1.5969663402619119,
#  2,
#  6.5,
#  1.4832391078026128,
#  2,
#  6.6,
#  1.3751417739675347,
#  2,
#  6.699999999999999,
#  1.2727679342144482,
#  2,
#  6.800000000000001,
#  1.176147024647256,
#  2,
#  6.9,
#  1.0852507395186182,
#  2,
#  7.0,
#  1.0,
#  4,
#  0.0,
#  2.8802547454843725e-12,
#  4,
#  0.10000000000000009,
#  1.3861870276544553e-07,
#  4,
#  0.20000000000000018,
#  0.0014790825004879875,
#  4,
#  0.30000000000000027,
#  0.173216337144564,
#  4,
#  0.3999999999999999,
#  0.7625428097226046,
#  4,
#  0.5,
#  1.3992708254931923,
#  4,
#  0.6000000000000001,
#  1.9997228328586563,
#  4,
#  0.7000000000000002,
#  2.525583011547672,
#  4,
#  0.8000000000000003,
#  2.97220361332301,
#  4,
#  0.8999999999999999,
#  3.3496026663600564,
#  4,
#  1.0,
#  3.6702529517533753,
#  4,
#  1.1,
#  3.945304352996752,
#  4,
#  1.2000000000000002,
#  4.183874075228861,
#  4,
#  1.3,
#  4.3931796975424975,
#  4,
#  1.4000000000000001,
#  4.578848765365415,
#  4,
#  1.5,
#  4.745224542560536,
#  4,
#  1.6,
#  4.895623450955622,
#  4,
#  1.7000000000000002,
#  5.032539275225706,
#  4,
#  1.8,
#  5.157801536455179,
#  4,
#  1.9000000000000001,
#  5.27269866715036,
#  4,
#  2.0,
#  5.378076292425909,
#  4,
#  2.1,
#  5.474419140142475,
#  4,
#  2.2,
#  5.561922773456203,
#  4,
#  2.3000000000000003,
#  5.640558910393019,
#  4,
#  2.4000000000000004,
#  5.710135872801945,
#  4,
#  2.5,
#  5.770353963236022,
#  4,
#  2.6,
#  5.820854518770131,
#  4,
#  2.7,
#  5.861261120937919,
#  4,
#  2.8000000000000003,
#  5.891211855799528,
#  4,
#  2.9000000000000004,
#  5.9103823640137785,
#  4,
#  3.0,
#  5.918500375067084,
#  4,
#  3.1,
#  5.915353201075178,
#  4,
#  3.2,
#  5.9007901101690985,
#  4,
#  3.3000000000000003,
#  5.8747215779700115,
#  4,
#  3.4000000000000004,
#  5.837117198679697,
#  4,
#  3.5,
#  5.788003640775756,
#  4,
#  3.6,
#  5.7274635696294425,
#  4,
#  3.7,
#  5.655636014632391,
#  4,
#  3.8000000000000003,
#  5.572718279621665,
#  4,
#  3.9000000000000004,
#  5.478969200785434,
#  4,
#  4.0,
#  5.3747133451185105,
#  4,
#  4.1000000000000005,
#  5.260345605458139,
#  4,
#  4.2,
#  5.136335573992749,
#  4,
#  4.3,
#  5.003231055600619,
#  4,
#  4.4,
#  4.8616601089678495,
#  4,
#  4.5,
#  4.712331072811544,
#  4,
#  4.6000000000000005,
#  4.556030142963963,
#  4,
#  4.7,
#  4.3936162088028174,
#  4,
#  4.800000000000001,
#  4.22601282748656,
#  4,
#  4.9,
#  4.0541974015296685,
#  4,
#  5.0,
#  3.8791878164635167,
#  4,
#  5.1000000000000005,
#  3.70202697557016,
#  4,
#  5.2,
#  3.5237658224611392,
#  4,
#  5.300000000000001,
#  3.34544555550896,
#  4,
#  5.4,
#  3.168079800169067,
#  4,
#  5.5,
#  2.9926375104115728,
#  4,
#  5.6000000000000005,
#  2.820027319048622,
#  4,
#  5.7,
#  2.651083954862898,
#  4,
#  5.800000000000001,
#  2.4865572032778402,
#  4,
#  5.9,
#  2.3271037214742387,
#  4,
#  6.0,
#  2.173281844366616,
#  4,
#  6.1000000000000005,
#  2.0255493500749377,
#  4,
#  6.2,
#  1.8842640054729762,
#  4,
#  6.300000000000001,
#  1.7496865934475445,
#  4,
#  6.4,
#  1.6219860389631255,
#  4,
#  6.5,
#  1.5012462020910708,
#  4,
#  6.6000000000000005,
#  1.3874738906249056,
#  4,
#  6.7,
#  1.280607657974572,
#  4,
#  6.800000000000001,
#  1.180526987417135,
#  4,
#  6.9,
#  1.087061514615392,
#  4,
#  7.0,
#  1.0,
#  6,
#  0.0,
#  8.396748683494155e-27,
#  6,
#  0.09999999999999964,
#  4.0196613456154396e-22,
#  6,
#  0.20000000000000018,
#  1.3739253208898264e-17,
#  6,
#  0.2999999999999998,
#  3.8620234379928273e-13,
#  6,
#  0.3999999999999999,
#  5.6823759403153544e-09,
#  6,
#  0.5,
#  2.65482429065631e-06,
#  6,
#  0.6000000000000001,
#  0.00022799070759552947,
#  6,
#  0.7000000000000002,
#  0.004362228076386457,
#  6,
#  0.7999999999999998,
#  0.018019875295401316,
#  6,
#  0.8999999999999999,
#  0.05006894622169866,
#  6,
#  1.0,
#  0.11607299890310546,
#  6,
#  1.1,
#  0.2294154930679044,
#  6,
#  1.2000000000000002,
#  0.3938488936132962,
#  6,
#  1.2999999999999998,
#  0.6029629269764488,
#  6,
#  1.4000000000000004,
#  0.8450179144730346,
#  6,
#  1.5,
#  1.10705795258012,
#  6,
#  1.6,
#  1.3770035066035622,
#  6,
#  1.7000000000000002,
#  1.644872300536924,
#  6,
#  1.7999999999999998,
#  1.9034921196374204,
#  6,
#  1.9000000000000004,
#  2.1485835514755407,
#  6,
#  2.0,
#  2.3783044592259275,
#  6,
#  2.1,
#  2.592546381950086,
#  6,
#  2.2,
#  2.7922438102774194,
#  6,
#  2.3000000000000003,
#  2.9788290004958022,
#  6,
#  2.4000000000000004,
#  3.1538574630143565,
#  6,
#  2.5,
#  3.318774905785669,
#  6,
#  2.6,
#  3.474782532652275,
#  6,
#  2.7,
#  3.622763850840098,
#  6,
#  2.8000000000000003,
#  3.763248275178764,
#  6,
#  2.9000000000000004,
#  3.89639793102134,
#  6,
#  3.0,
#  4.022011979146301,
#  6,
#  3.1,
#  4.139547427106924,
#  6,
#  3.2,
#  4.248157266798985,
#  6,
#  3.3000000000000003,
#  4.346746490452776,
#  6,
#  3.4000000000000004,
#  4.434044745350473,
#  6,
#  3.5,
#  4.5086918705018,
#  6,
#  3.6,
#  4.569330181346239,
#  6,
#  3.7,
#  4.61469590838855,
#  6,
#  3.8000000000000003,
#  4.6437021149458735,
#  6,
#  3.9000000000000004,
#  4.655506723615816,
#  6,
#  4.0,
#  4.649561555654126,
#  6,
#  4.1000000000000005,
#  4.625640894455554,
#  6,
#  4.2,
#  4.583850415865831,
#  6,
#  4.3,
#  4.524618992171118,
#  6,
#  4.4,
#  4.448676755837397,
#  6,
#  4.5,
#  4.3570230067505475,
#  6,
#  4.6000000000000005,
#  4.250887280625963,
#  6,
#  4.7,
#  4.131686397962442,
#  6,
#  4.800000000000001,
#  4.000979764049308,
#  6,
#  4.9,
#  3.860424700384186,
#  6,
#  5.0,
#  3.711733199579966,
#  6,
#  5.1000000000000005,
#  3.5566312067048704,
#  6,
#  5.2,
#  3.39682131334703,
#  6,
#  5.300000000000001,
#  3.23394957369388,
#  6,
#  5.4,
#  3.0695769869544263,
#  6,
#  5.5,
#  2.9051560204368547,
#  6,
#  5.6000000000000005,
#  2.7420123669680994,
#  6,
#  5.7,
#  2.581331942971517,
#  6,
#  5.800000000000001,
#  2.424152949376084,
#  6,
#  5.9,
#  2.2713626490474326,
#  6,
#  6.0,
#  2.123698373283658,
#  6,
#  6.1000000000000005,
#  1.9817521648117051,
#  6,
#  6.2,
#  1.845978400234177,
#  6,
#  6.300000000000001,
#  1.7167037112152914,
#  6,
#  6.4,
#  1.5941385373123138,
#  6,
#  6.5,
#  1.4783896879147007,
#  6,
#  6.6000000000000005,
#  1.369473358354241,
#  6,
#  6.7,
#  1.2673281275597146,
#  6,
#  6.800000000000001,
#  1.171827553810399,
#  6,
#  6.9,
#  1.0827920744857746,
#  6,
#  7.0,
#  1.0,
#  8,
#  0.0,
#  8.28666694115842e-42,
#  8,
#  0.09999999999999964,
#  3.7780423180264256e-37,
#  8,
#  0.20000000000000018,
#  1.4083416577487033e-32,
#  8,
#  0.2999999999999998,
#  4.795209880509597e-28,
#  8,
#  0.40000000000000036,
#  1.4996877582106393e-23,
#  8,
#  0.5,
#  4.2152058540832136e-19,
#  8,
#  0.6000000000000005,
#  8.019444973729894e-15,
#  8,
#  0.7000000000000002,
#  5.859339872065299e-12,
#  8,
#  0.7999999999999998,
#  7.299687540466635e-10,
#  8,
#  0.9000000000000004,
#  7.031555063197974e-08,
#  8,
#  1.0,
#  2.9775144945819905e-06,
#  8,
#  1.1000000000000005,
#  2.025235236872005e-05,
#  8,
#  1.2000000000000002,
#  7.140306108692413e-05,
#  8,
#  1.2999999999999998,
#  0.00022694224000736747,
#  8,
#  1.4000000000000004,
#  0.0006792667137841198,
#  8,
#  1.5,
#  0.0018958987294292004,
#  8,
#  1.6,
#  0.0048464410276599056,
#  8,
#  1.7000000000000002,
#  0.011169225133634044,
#  8,
#  1.7999999999999998,
#  0.023080862630738934,
#  8,
#  1.9000000000000004,
#  0.04306993848619666,
#  8,
#  2.0,
#  0.07362733607734052,
#  8,
#  2.1,
#  0.11701132017245593,
#  8,
#  2.2,
#  0.17483431728398466,
#  8,
#  2.3000000000000003,
#  0.24749318312658125,
#  8,
#  2.4000000000000004,
#  0.33375985493087007,
#  8,
#  2.5,
#  0.43084982399762656,
#  8,
#  2.6,
#  0.5350068218888808,
#  8,
#  2.7,
#  0.6423319126670264,
#  8,
#  2.8000000000000003,
#  0.7494926087901151,
#  8,
#  2.9000000000000004,
#  0.8540965835571659,
#  8,
#  3.0,
#  0.9547302988107025,
#  8,
#  3.1,
#  1.0507879897920953,
#  8,
#  3.2,
#  1.1422267806925024,
#  8,
#  3.3000000000000003,
#  1.2293359918339903,
#  8,
#  3.4000000000000004,
#  1.3125570478420725,
#  8,
#  3.5,
#  1.3923572297421272,
#  8,
#  3.6,
#  1.4691462574374508,
#  8,
#  3.7,
#  1.5432223518087989,
#  8,
#  3.8000000000000003,
#  1.6147373747254212,
#  8,
#  3.9000000000000004,
#  1.6836748401073087,
#  8,
#  4.0,
#  1.749838226023731,
#  8,
#  4.1000000000000005,
#  1.812849524366327,
#  8,
#  4.2,
#  1.8721592468886366,
#  8,
#  4.3,
#  1.9270692154298383,
#  8,
#  4.4,
#  1.976768543663899,
#  8,
#  4.5,
#  2.020381555237533,
#  8,
#  4.6000000000000005,
#  2.0570244330104615,
#  8,
#  4.7,
#  2.0858657075376263,
#  8,
#  4.800000000000001,
#  2.1061847640220366,
#  8,
#  4.9,
#  2.117422647907191,
#  8,
#  5.0,
#  2.1192205433173754,
#  8,
#  5.1000000000000005,
#  2.1114430771490547,
#  8,
#  5.2,
#  2.0941856198077633,
#  8,
#  5.300000000000001,
#  2.067766590104055,
#  8,
#  5.4,
#  2.032707142651804,
#  8,
#  5.5,
#  1.9897014106279558,
#  8,
#  5.6000000000000005,
#  1.9395807291572646,
#  8,
#  5.7,
#  1.8832750946125465,
#  8,
#  5.800000000000001,
#  1.8217746700379922,
#  8,
#  5.9,
#  1.7560935617105344,
#  8,
#  6.0,
#  1.6872374705017243,
#  8,
#  6.1000000000000005,
#  1.6161762337947012,
#  8,
#  6.2,
#  1.5438217597312878,
#  8,
#  6.300000000000001,
#  1.4710114344419445,
#  8,
#  6.4,
#  1.3984967592780104,
#  8,
#  6.5,
#  1.3269367446285336,
#  8,
#  6.6000000000000005,
#  1.2568954401305263,
#  8,
#  6.7,
#  1.188842905655218,
#  8,
#  6.800000000000001,
#  1.123158909815709,
#  8,
#  6.9,
#  1.0601386692784647,
#  8,
#  7.0,
#  1.0,
#  10,
#  0.0,
#  6.086102287937499e-57,
#  10,
#  0.09999999999999964,
#  2.6782375941525107e-52,
#  10,
#  0.20000000000000018,
#  1.0350511218937004e-47,
#  10,
#  0.2999999999999998,
#  3.762541438849064e-43,
#  10,
#  0.40000000000000036,
#  1.2957477874758365e-38,
#  10,
#  0.5,
#  4.2208209759682024e-34,
#  10,
#  0.6000000000000005,
#  1.293284162719767e-29,
#  10,
#  0.7000000000000002,
#  3.6747560563554616e-25,
#  10,
#  0.7999999999999998,
#  8.208741100015259e-21,
#  10,
#  0.9000000000000004,
#  9.583623091070258e-18,
#  10,
#  1.0,
#  1.3103603884122906e-15,
#  10,
#  1.1000000000000005,
#  1.535016733923659e-13,
#  10,
#  1.2000000000000002,
#  1.5684678414719767e-11,
#  10,
#  1.2999999999999998,
#  1.0413563875986248e-09,
#  10,
#  1.4000000000000004,
#  1.2769987896863982e-08,
#  10,
#  1.5,
#  4.969679836152466e-08,
#  10,
#  1.6000000000000005,
#  1.6709449096016273e-07,
#  10,
#  1.7000000000000002,
#  5.475580444073536e-07,
#  10,
#  1.7999999999999998,
#  1.7616064930140795e-06,
#  10,
#  1.9000000000000004,
#  5.5434501588548165e-06,
#  10,
#  2.0,
#  1.691932525950689e-05,
#  10,
#  2.1000000000000005,
#  4.94399671927937e-05,
#  10,
#  2.2,
#  0.00013603253440358835,
#  10,
#  2.3000000000000003,
#  0.0003465626119154833,
#  10,
#  2.4000000000000004,
#  0.0008084711478873595,
#  10,
#  2.5,
#  0.0017256232747837775,
#  10,
#  2.6,
#  0.003400028927224667,
#  10,
#  2.7,
#  0.0062663632082374165,
#  10,
#  2.8000000000000003,
#  0.010934059914971657,
#  10,
#  2.9000000000000004,
#  0.018210905714226882,
#  10,
#  3.0,
#  0.029071456513636837,
#  10,
#  3.1,
#  0.04453648534977107,
#  10,
#  3.2,
#  0.06545606793238172,
#  10,
#  3.3000000000000003,
#  0.09224556884266852,
#  10,
#  3.4000000000000004,
#  0.12468444565648108,
#  10,
#  3.5,
#  0.16189361494780954,
#  10,
#  3.6,
#  0.20252496506855655,
#  10,
#  3.7,
#  0.24507826866489194,
#  10,
#  3.8000000000000003,
#  0.28820336084834514,
#  10,
#  3.9000000000000004,
#  0.33088506554010155,
#  10,
#  4.0,
#  0.3724919197176862,
#  10,
#  4.1000000000000005,
#  0.4127291241463914,
#  10,
#  4.2,
#  0.4515497942160428,
#  10,
#  4.3,
#  0.48906382737165355,
#  10,
#  4.4,
#  0.5254631881319153,
#  10,
#  4.5,
#  0.5609676552805429,
#  10,
#  4.6000000000000005,
#  0.5957878622277302,
#  10,
#  4.7,
#  0.6301005469918313,
#  10,
#  4.800000000000001,
#  0.6640316476959386,
#  10,
#  ...]

# %%
# Out:
#       0           1_x           1_y
# 0   0.0  2.880255e-12  8.396749e-27
# 1   0.2  1.479083e-03  1.373925e-17
# 2   0.4  7.625428e-01  5.682376e-09
# 3   0.5  1.399271e+00  2.654824e-06
# 4   0.6  1.999723e+00  2.279907e-04
# ..  ...           ...           ...
# 59  6.6  1.387474e+00  1.369473e+00
# 60  6.7  1.280608e+00  1.267328e+00
# 61  6.8  1.180527e+00  1.171828e+00
# 62  6.9  1.087062e+00  1.082792e+00
# 63  7.0  1.000000e+00  1.000000e+00
#
# [64 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 range(1,5)[4]
#
# IndexError: range object index out of range
